# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Loading

# %%
evaluation_data = pd.read_csv('results/one_digit_mask_length_n.csv')
evaluation_data.head(10)
# Out:
#   Algorithm  Samples  Execution  Generation Time  Sample Time
# 0  Outlines       50          0         3.333263     2.707712
# 1      PDFA       50          0         6.685310     0.009241
# 2      GPT2       50          0         0.000000     3.430954
# 3  Outlines     1000          0         3.381144    39.232384
# 4      PDFA     1000          0         6.408477     0.131081
# 5      GPT2     1000          0         0.000000    72.071501
# 6  Outlines     3000          0         3.352968   137.315329
# 7      PDFA     3000          0         6.473107     0.353452
# 8      GPT2     3000          0         0.000000   228.008260
# 9  Outlines     5000          0         3.310630   205.092562

# %%
evaluation_data['Time'] = evaluation_data['Generation Time'] + evaluation_data['Sample Time']
evaluation_data.head(10)
# Out:
#   Algorithm  Samples  Execution  Generation Time  Sample Time        Time
# 0  Outlines       50          0         3.333263     2.707712    6.040975
# 1      PDFA       50          0         6.685310     0.009241    6.694551
# 2      GPT2       50          0         0.000000     3.430954    3.430954
# 3  Outlines     1000          0         3.381144    39.232384   42.613528
# 4      PDFA     1000          0         6.408477     0.131081    6.539558
# 5      GPT2     1000          0         0.000000    72.071501   72.071501
# 6  Outlines     3000          0         3.352968   137.315329  140.668297
# 7      PDFA     3000          0         6.473107     0.353452    6.826559
# 8      GPT2     3000          0         0.000000   228.008260  228.008260
# 9  Outlines     5000          0         3.310630   205.092562  208.403192

# %%
sns.set_style("whitegrid")

evaluation_data_filtered = evaluation_data[evaluation_data['Samples'] != 50]


sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
ax = sns.boxplot(x="Samples", y="Time", hue="Algorithm", data=evaluation_data_filtered, dodge=False)
ax.set_title('Generate + Sample Time')
ax.set_xlabel('Samples')
ax.set_ylabel('Time')

plt.legend(title='Algorithm', loc='upper left', bbox_to_anchor=(0.02, 0.98))

plt.tight_layout()
plt.show()

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(4, 3))
ax = sns.lineplot(x="Samples", y="Time", hue="Algorithm", data=evaluation_data_filtered, errorbar='sd', marker='o')
ax.set_title('Generate + Sample Time')
ax.set_xlabel('Samples')
ax.set_ylabel('Sample Time')

plt.legend(title='Algorithm', loc='upper left')

plt.tight_layout()
plt.show()
